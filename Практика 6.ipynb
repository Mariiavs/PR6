# %% [markdown]
# <h1>Практика 6</h1>
# <h4>Задание на лабораторную работу</h4>
# <p>Разработать программу, моделирующую один из алгоритмов управления памятью в соответствии с вариантом задания. При моделировании считать что:</p>
# <ul>
#     <li>объем моделируемой «памяти» составляет 64К</li>
#     <li>поступаемые на выполнение задачи содержатся в файлах, которые пользователь может «загружать» в моделируемую «память» и выгружать из нее (файл моделирует лишь размер задачи)</li>
#     <li>размер задачи в диапазоне от 0 до 65535 байт</li>
# </ul>
# <p>Программа должна иметь возможность просмотра состояния моделируемой «памяти».</p>
# <h4>Вариант 6</h4>
# <p>Сегментное распределение памяти </p>

# %%
import numpy as np
import string

def search(segm, n):
    
    i = [-1 for j in range(n)]
    j = 0
    
    while j < n:
        k = j
        r = True
        while r:
            i[j] = np.random.randint(20)
            if (segm[i[j],0] == 0):
                r = False
                
        while k < n-1:
            if (segm[i[k]+1,0] == 0)and(i[k] < 19):
                i[k+1] = i[k]+1
                k += 1
            else:
                break

        j = k+1
        
    return i

segm = np.zeros((20, 2), dtype=int)
    
q = 0
i = 0
v = 0
ch = 0

print('\n1. Добавить задачу\n2. Удалить задачу\n3. Состояние памяти\n4. Выход\n')

while ch != 4:
    ch = int(input('\nВыбор: '))
    
    if ch == 1:
        q = int(input('Размер(Кбайт): '))
        
        if v + q > 64:
            print ('Переполнение памяти')
        else:
            v += q
        
            if q < 17:
                l = search(segm, 1)
                segm[l[0]] = [ord(string.ascii_letters[i]), q]

            elif q < 33:
                l = search(segm, 2)
                segm[l[0]] = [ord(string.ascii_letters[i]), q//2]
                segm[l[1]] = [ord(string.ascii_letters[i]), q//2+q%2]

            elif q < 49:
                l = search(segm, 3)
                segm[l[0]] = [ord(string.ascii_letters[i]), q//3]
                segm[l[1]] = [ord(string.ascii_letters[i]), q//3]
                segm[l[2]] = [ord(string.ascii_letters[i]), q//3+q%3]

            else:
                l = search(segm, 4)
                segm[l[0]] = [ord(string.ascii_letters[i]), q//4]
                segm[l[1]] = [ord(string.ascii_letters[i]), q//4]
                segm[l[2]] = [ord(string.ascii_letters[i]), q//4]
                segm[l[3]] = [ord(string.ascii_letters[i]), q//4+q%4]

            i += 1
            
    if ch == 2:
        q = input('Задача: ')
        
        for j in range(20):
            
            if segm[j, 0] == ord(q):
                v -= segm[j, 1]
                segm[j] = [0, 0]
                
    if ch == 3:
        
        for j in range(20):
            if segm[j, 0] != 0:
                print(chr(segm[j, 0]),' - ', segm[j, 1])
# Out:
# 1. Добавить задачу
# 2. Удалить задачу
# 3. Состояние памяти
# 4. Выход
#
#
# Выбор: 1
# Размер(Кбайт): 20
#
# Выбор: 1
# Размер(Кбайт): 40
#
# Выбор: 3
# a  -  10
# a  -  10
# b  -  13
# b  -  13
# b  -  14
#
# Выбор: 2
# Задача: b
#
# Выбор: 3
# a  -  10
# a  -  10
#
# Выбор: 2
# Задача: a
#
# Выбор: 1
# Размер(Кбайт): 1
#
# Выбор: 1
# Размер(Кбайт): 2
#
# Выбор: 1
# Размер(Кбайт): 1
#
# Выбор: 1
# Размер(Кбайт): 2
#
# Выбор: 1
# Размер(Кбайт): 33
#
# Выбор: 3
# g  -  11
# g  -  11
# g  -  11
# e  -  1
# f  -  2
# c  -  1
# d  -  2
#
# Выбор: 4
